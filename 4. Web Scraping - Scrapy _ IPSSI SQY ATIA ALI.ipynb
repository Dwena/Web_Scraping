# %% [markdown]
# # 4. Web Scraping - Scrapy
#
# <img src='https://xn--kvin-duranty-beb.fr/wp-content/uploads/2022/10/Web-Scraping-_-IPSSI-PRS-3.png'>
#
# Dans cet exercice, nous utiliserons la bibliothèque scrapy afin de collecter les données des sites internet suivants :
#
# - Partie 1 : [AlloCiné](https://www.allocine.fr/film/meilleurs)
# Nous collecterons les informations des meilleurs films recensés par la platforme.
#
#
# - Partie 2 : [Boursorama](https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC)
# Nous collecterons les données boursières des entreprises du CAC40.

# %% [markdown]
# # Parie 1 - Les meilleurs films selon [Allociné.fr](https://www.allocine.fr/film/meilleurs/)
#
# <img src= 'https://fr.web.img2.acsta.net/newsv7/15/10/19/21/14/237930.jpg'>
#
# L'objectif de cet exercice est de collecter les données des meilleurs films présents sur la page `https://www.allocine.fr/film/meilleurs/` du site allocine.fr.
#
# Les données que nous collecterons seront les suivantes :
# - Les titres du film
# - Les liens des images
# - Les noms des auteurs
# - Les durées des films
# - Les genres cinématographiques
# - Les scores des films
# - Les descriptions des films
# - Les dates de sortie des films
#
# ## 4.1 Installez scrapy à l'aide de la commande suivante :
#
#
# `pip install scrapy`

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (2.11.0)
# Requirement already satisfied: Twisted<23.8.0,>=18.9.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=36.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (41.0.7)
# Requirement already satisfied: cssselect>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (23.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (23.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (6.1)
# Requirement already satisfied: protego>=0.1.15 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: itemadapter>=0.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (56.0.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (23.1)
# Requirement already satisfied: tldextract in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (5.1.1)
# Requirement already satisfied: lxml>=4.4.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from cryptography>=36.0.0->scrapy) (1.15.1)
# Requirement already satisfied: jmespath>=0.9.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from service-identity>=18.1.0->scrapy) (0.5.0)
# Requirement already satisfied: pyasn1-modules in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: constantly>=15.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: incremental>=21.3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (4.9.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tldextract->scrapy) (3.3)
# Requirement already satisfied: requests>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tldextract->scrapy) (2.28.1)
# Requirement already satisfied: requests-file>=1.4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from tldextract->scrapy) (3.12.4)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from Automat>=0.8.0->Twisted<23.8.0,>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests>=2.1.0->tldextract->scrapy) (2022.6.15)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %% [markdown]
# ## 4.2 Générez un environement de travail scrapy en executant la commande suivante :

# %%
# Création du dossier WebCrawler contenant l'ensemble des fichiers utiles au fonctionnement de scrapy
# !scrapy startproject WebCrawler
# Out:
# New Scrapy project 'WebCrawler', using template directory '/opt/anaconda3/envs/chess/lib/python3.8/site-packages/scrapy/templates/project', created in:
#     /Users/kevinduranty/Desktop/Kevin Duranty - Web scraping /WebCrawler
#
# You can start your first spider with:
#     cd WebCrawler
#     scrapy genspider example example.com

# %%
# Création du projet AlloCiné dans le dossier WebCrawler/spider
# !cd WebCrawler && scrapy genspider allocine https://www.allocine.fr/film/meilleurs
# Out:
# Created spider 'allocine' using template 'basic' in module:
#   WebCrawler.spiders.allocine

# %% [markdown]
# Les fichiers de scrapy que nous manipulerons seront :
#
# 1. le fichier `items.py` qui contient les champ que nous souhaitons collecter (ex : nom des films, score, date de publication). Chaque champs sera introduit dans la class `ReviewsAllocineItem` avec la nomenclature suivante : `name = scrapy.Field()`.
#
#
# 2. le fichier `allocine.py` qui contient les fonctions permettant la collecte.

# %% [markdown]
# ## 4.3 Ajoutez dans le fichier `items.py` les champs que nous souhaitons collecter.
#
# Ajoutez dans la class `ReviewsAllocineItem(scrapy.Item)` les champs suivants,
# pour rappel la nomenclature des champs est la suivante :
#
# `name = scrapy.Field()`.
#
# - title
# - img
# - author
# - time
# - genre
# - score
# - desc
# - release
# - page

# %%
#À ajouter au fichier items.py
class ReviewsAllocineItem(scrapy.Item):  
     title = scrapy.Field()
     img    = scrapy.Field()
     author = scrapy.Field()
     time   = scrapy.Field()
     genre  = scrapy.Field()
     score  = scrapy.Field()
     desc   = scrapy.Field()
     release = scrapy.Field()
     page    = scrapy.Field()

# %% [markdown]
# ## 4.3 Lancez votre terminal puis exécutez la commande suivante :
#
# C'est dans le terminale que nous intéragirons avec scrapy pour manipuler les bases du site allocine.fr

# %% [markdown]
# `scrapy shell`
#
# `url = 'https://www.allocine.fr/film/meilleurs'`
#
# `fetch(url)`

# %% [markdown]
# ## 4.4 Exécutez dans votre terminal les commandes suivantes et notez vos observations.
#
# Repérez les balises correspondantes.
#
# `response`
#
# `response.css('a')`
#
# `len(response.css('a'))`
#
# `response.css('a::text')`
#
# `response.css('a')[0].attrib`
#
# `response.css('a')[0].attrib['href']`
#
# `response.css('a::text')[0].extract()`
#
# `response.css('h1.item')`
#
# `response.css('h1.item::text')`
#
# `response.css('h1.item::text')[0].extract()`
#
# `response.css('img')`

# %% [markdown]
# ## 4.5 Recherchez les informations suivantes sous forme de chaine de caractère (str) :
#
# 0. La balise qui liste l'ensemble des films
# 1. Le titre du premier film
# 2. Le lien de l'image du premier film
# 3. Le nom de l'auteur du premier film
# 4. La durée du premier film
# 5. Le genre cinématographique du premier film
# 6. Le score du premier film
# 7. La description du premier film
# 8. La date de sortie du premier film

# %%
# 0. La balise qui liste l'ensemble des films
films = response.css('li.mdl')

#1. Le titre du premier film
title = films[0].css('a::text').get()

#2. Le lien de l'image du premier film
img = films[0].css('img').attrib['src']

#3. Le nom de l'auteur du premier film
author = films[0].css('a.blue-link::text').get()

#4. La durée du premier film
time = films[0].css('div.meta-body-item.meta-body-info::text').get()

#5. Le genre cinématographique du premier film
genre = films[0].css('div.meta-body-item.meta-body-info span::text').getall()

#6. Le score du premier film
score = films[0].css('span.stareval-note::text').get()

#7. La description du premier film
desc = films[0].css('div.content-txt::text').get()

#8. La date de sortie du premier film
release = films[0].css('span.date::text').get()

# %% [markdown]
# ## 4.6 Complétez le code suivante en fonction des résultats obtenus à la question précédentes

# %%
import scrapy
from scrapy import Request
from WebCrawler.items import ReviewsAllocineItem


class AllocineSpider(scrapy.Spider):
    name = 'allocine'
    allowed_domains = ['www.allocine.fr']

    #Liste des pages à collecter
    start_urls = [f'https://www.allocine.fr/film/meilleurs/?page={n}' for n in range(1,10)]

    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_allocine)

    def parse_allocine(self, response):
        liste_film = response.css('li.mdl')


        # Boucle qui parcours l'ensemble des éléments de la liste des films
        for film in liste_film:
            item = ReviewsAllocineItem()

            # Nom du film
            try:item['title'] = film.css('a::text').get()
            except:item['title'] = 'None'

            # Lien de l'image du film
            try:item['img'] = film.css('img').attrib['src']
            except:item['img'] = 'None'

            # Auteur du film
            try:item['author'] = film.css('a.blue-link::text').get()
            except:item['author'] = 'None'

            # Durée du film
            try:item['time'] = film.css('div.meta-body-item.meta-body-info::text').get()
            except:item['time'] = 'None'

            # Genre cinématographique
            try:item['genre'] = film.css('div.meta-body-item.meta-body-info span::text').getall()
            except: item['genre'] = 'None'

            # Score du film
            try:item['score'] = film.css('span.stareval-note::text').get()
            except:item['score'] = 'None'

            # Description du film
            try:item['desc'] = film.css('div.content-txt::text').get()
            except:item['desc'] = 'None'

            # Date de sortie
            try:item['release'] = film.css('span.date::text').get()
            except:item['release'] = 'None'

            yield item

# %% [markdown]
# ## 4.7 Ajoutez l'ensemble de votre code au fichier `allocine.py` se trouvant dans le dossier `spider`, exécutant la commande suivante afin d'obtenir le fichier `allocine.csv` contenant les données collectées.

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl allocine -o allocine.json
# Out:
# 2024-01-04 10:50:08 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: WebCrawler)
# 2024-01-04 10:50:08 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.9.13, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.8.16 (default, Mar  1 2023, 21:19:10) - [Clang 14.0.6 ], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform macOS-10.16-x86_64-i386-64bit
# 2024-01-04 10:50:08 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-04 10:50:08 [asyncio] DEBUG: Using selector: KqueueSelector
# 2024-01-04 10:50:08 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-01-04 10:50:08 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-01-04 10:50:08 [scrapy.extensions.telnet] INFO: Telnet Password: 39501358974afdbb
# 2024-01-04 10:50:08 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2024-01-04 10:50:08 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'WebCrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'WebCrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['WebCrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-01-04 10:50:09 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-01-04 10:50:09 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-01-04 10:50:09 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-01-04 10:50:09 [scrapy.core.engine] INFO: Spider opened
# 2024-01-04 10:50:09 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-04 10:50:09 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/robots.txt> (referer: None)
# 2024-01-04 10:50:12 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://www.allocine.fr/film/meilleurs/> from <GET https://www.allocine.fr/film/meilleurs/?page=1>
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=5> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=9> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=7> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=3> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=6> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=4> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=8> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/?page=2> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.allocine.fr/film/meilleurs/> (referer: None)
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Tony Kaye',
#  'desc': '\n'
#          'Derek veut venger la mort de son père, abattu par un dealer noir, et '
#          "épouse les thèses racistes d'un groupuscule de militants d'extrême "
#          'droite. Ces théories le mèneront à commettre un double meurtre...\n',
#  'genre': ['/', 'Drame', 'Policier'],
#  'img': 'https://fr.web.img6.acsta.net/c_310_420/medias/03/26/20/032620_af.jpg',
#  'release': None,
#  'score': '2,8',
#  'time': '\n1h 59min\n',
#  'title': 'American History X'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Alfred Hitchcock',
#  'desc': '\nUne jeune femme en fuite trouve refuge dans un motel isolé...\n',
#  'genre': ['/', 'Thriller', 'Epouvante-horreur'],
#  'img': 'https://fr.web.img6.acsta.net/c_310_420/pictures/22/04/06/14/34/3532106.jpg',
#  'release': '6 avril 2022',
#  'score': '4,5',
#  'time': '\n1h 49min\n',
#  'title': 'Psychose'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'George Lucas',
#  'desc': '\n'
#          'Il y a bien longtemps, dans une galaxie très lointaine... La guerre '
#          "civile fait rage entre l'Empire galactique et l'Alliance rebelle.\n",
#  'genre': ['/', 'Science Fiction', 'Aventure'],
#  'img': '...',
#  'release': '12 mars 1997',
#  'score': '4,8',
#  'time': '\n2h 01min\n',
#  'title': 'Star Wars : Episode IV - Un nouvel espoir (La Guerre des étoiles)'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Richard Marquand',
#  'desc': '\n'
#          "L'Empire galactique est plus puissant que jamais : la construction "
#          "de la nouvelle arme, l'Etoile de la Mort, menace l'univers tout "
#          'entier...\n',
#  'genre': ['/', 'Science Fiction', 'Aventure'],
#  'img': '...',
#  'release': '23 avril 1997',
#  'score': '3,0',
#  'time': '\n2h 13min\n',
#  'title': 'Star Wars : Episode VI - Le Retour du Jedi'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Hayao Miyazaki',
#  'desc': '\n'
#          'Chihiro, une fillette de 10 ans, est en route vers sa nouvelle '
#          'demeure en compagnie de ses parents. Au cours du voyage, la famille '
#          'fait une halte dans un parc à thème qui leur paraît délabré. Lors de '
#          'la visite, les parents s’arrêtent dans un des bâtiments pour '
#          'déguster quelques mets très appétissants, apparus comme par '
#          'enchantement. Hélas cette nourriture les transforme en porcs. Prise '
#          'de panique, Chihiro s’enfuit et se retrouve seule dans cet univers '
#          'fantasmagorique ; elle rencontre alors l’énigmatique Haku, son seul '
#          'allié dans cette terrible épreuve...\n',
#  'genre': ['/', 'Animation', 'Aventure', 'Fantastique'],
#  'img': '...',
#  'release': None,
#  'score': '4,8',
#  'time': '\n2h 05min\n',
#  'title': 'Le Voyage de Chihiro'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Todd Phillips',
#  'desc': '\n'
#          'Le film, qui relate une histoire originale inédite sur grand écran, '
#          'se focalise sur la figure emblématique de l’ennemi juré de Batman. '
#          'Il brosse le portrait d’Arthur Fleck, un homme sans concession '
#          'méprisé par la société.\n',
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': '7 juin 2023',
#  'score': '4,1',
#  'time': '\n2h 02min\n',
#  'title': 'Joker'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Clint Eastwood',
#  'desc': '\n'
#          "Replié sur lui-même, l'entraîneur Frankie Dunn vit dans un désert "
#          'affectif, en évitant toute relation qui pourrait accroître sa '
#          'douleur et sa culpabilité. Un jour, une trentenaire pousse la porte '
#          "de son gymnase à la recherche d'un coach...\n",
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': None,
#  'score': '4,9',
#  'time': '\n2h 12min\n',
#  'title': 'Million Dollar Baby'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Garth Davis',
#  'desc': '\n'
#          'Une incroyable histoire vraie\xa0: \xa0à 5 ans, Saroo se retrouve '
#          'seul dans un train traversant l’Inde qui l’emmène malgré lui à des '
#          'milliers de kilomètres de sa famille. Perdu, le petit garçon doit '
#          'apprendre à survivre seul dans l’immense ville de Calcutta.\n',
#  'genre': ['/', 'Biopic', 'Drame'],
#  'img': '...',
#  'release': None,
#  'score': '3,1',
#  'time': '\n1h 58min\n',
#  'title': 'Lion'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Charles Chaplin',
#  'desc': '\n'
#          'Un vagabond s’éprend d’une belle et jeune vendeuse de fleurs aveugle '
#          'qui vit avec sa mère, couverte de dettes. Suite à un quiproquo, la '
#          'fleuriste s’imagine le misérable, qui vient de lui acheter une '
#          'fleur, en milliardaire...\n',
#  'genre': ['/', 'Comédie dramatique', 'Romance'],
#  'img': '...',
#  'release': '10 juillet 2019',
#  'score': '4,5',
#  'time': '\n1h 27min\n',
#  'title': 'Les Lumières de la ville'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=5>
# {'author': 'Francis Ford Coppola',
#  'desc': '\n'
#          "Cloîtré dans une chambre d'hôtel de Saïgon, le jeune capitaine "
#          "Willard, mal rasé et imbibé d'alcool, est sorti de sa prostration "
#          "par une convocation de l'état-major américain. Le général Corman lui "
#          'confie une mission qui doit rester secrète : éliminer le colonel '
#          'Kurtz, un militaire aux méthodes quelque peu expéditives...\n',
#  'genre': ['/', 'Guerre', 'Drame'],
#  'img': '...',
#  'release': '21 août 2019',
#  'score': '4,8',
#  'time': '\n3h 02min\n',
#  'title': 'Apocalypse Now Final Cut'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Bryan Singer',
#  'desc': '\n'
#          'Du succès fulgurant de Freddie Mercury à ses excès, risquant la '
#          'quasi-implosion du groupe, jusqu’à son retour triomphal sur scène '
#          'lors du concert Live Aid, alors qu’il était frappé par la maladie, '
#          'découvrez la vie exceptionnelle d’un homme qui continue d’inspirer '
#          'les outsiders, les rêveurs et tous ceux qui aiment la musique.\n',
#  'genre': ['/', 'Biopic', 'Drame'],
#  'img': 'https://fr.web.img5.acsta.net/c_310_420/pictures/18/05/15/16/26/2028013.jpg',
#  'release': None,
#  'score': '3,0',
#  'time': '\n2h 15min\n',
#  'title': 'Bohemian Rhapsody'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Alfred Hitchcock',
#  'desc': '\n'
#          "Rendu responsable de la mort d'un collègue, Scottie, sujet au "
#          'vertige, quitte la police. Une ancienne relation le contacte afin '
#          "qu'il suive son épouse, possédée selon lui par l'esprit de son "
#          "aïeule. Scottie s'éprend bientôt de la jeune femme.\n",
#  'genre': ['/', 'Thriller', 'Drame'],
#  'img': 'https://fr.web.img5.acsta.net/c_310_420/medias/nmedia/00/02/56/87/aff.jpg',
#  'release': '19 mai 2004',
#  'score': '3,8',
#  'time': '\n2h 09min\n',
#  'title': 'Sueurs froides'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Eric Toledano',
#  'desc': '\n'
#          'La rencontre improbable, touchante et drôle entre un riche '
#          'aristocrate, tétraplégique depuis un accident de parapente, et un '
#          'jeune de banlieue engagé par hasard pour être son aide à '
#          'domicile...\n',
#  'genre': ['/', 'Drame', 'Comédie', 'Biopic'],
#  'img': 'https://fr.web.img2.acsta.net/c_310_420/o_club-allocine-310x420.png_0_se/medias/nmedia/18/82/69/17/19806656.jpg',
#  'release': None,
#  'score': '3,7',
#  'time': '\n1h 52min\n',
#  'title': 'Intouchables'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Stanley Kubrick',
#  'desc': '\n'
#          'Durant la Première Guerre mondiale, le général français Mireau lance '
#          'une offensive suicidaire contre une position allemande imprenable. '
#          "Au moment de l'attaque, les soldats tombent par dizaines et leurs "
#          "compagnons refusent d'avancer...\n",
#  'genre': ['/', 'Guerre', 'Drame'],
#  'img': 'https://fr.web.img4.acsta.net/c_310_420/medias/nmedia/18/35/35/59/19658149.jpg',
#  'release': '23 mars 2011',
#  'score': '4,6',
#  'time': '\n1h 28min\n',
#  'title': 'Les Sentiers de la gloire'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Irvin Kershner',
#  'desc': '\n'
#          "Malgré la destruction de l'Etoile Noire, l'Empire maintient son "
#          'emprise sur la galaxie, et poursuit sans relâche sa lutte contre '
#          "l'Alliance rebelle. Basés sur la planète glacée de Hoth, les "
#          'rebelles essuient un assaut des troupes impériales...\n',
#  'genre': ['/', 'Science Fiction', 'Aventure'],
#  'img': 'https://fr.web.img2.acsta.net/c_310_420/medias/nmedia/00/02/44/28/empire.jpg',
#  'release': '9 avril 1997',
#  'score': '5,0',
#  'time': '\n2h 04min\n',
#  'title': "Star Wars : Episode V - L'Empire contre-attaque"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'David Fincher',
#  'desc': '\n'
#          'John Doe a decidé de nettoyer la societé des maux qui la rongent en '
#          'commettant sept meurtres bases sur les sept pechés capitaux.\n',
#  'genre': ['/', 'Policier', 'Thriller', 'Drame'],
#  'img': 'https://fr.web.img6.acsta.net/c_310_420/medias/nmedia/18/35/91/33/19255605.jpg',
#  'release': None,
#  'score': '3,6',
#  'time': '\n2h 10min\n',
#  'title': 'Seven'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Charles Chaplin',
#  'desc': '\n'
#          '1898, Nord-Ouest du Canada. Alors que des milliers d’aventuriers '
#          'arpentent le Klondike en quête du métal précieux, Charlot est '
#          'surpris par une tempête de neige. Il trouve refuge dans une cabane '
#          'isolée et fait la rencontre de Big Jim McKay et du terrible Black '
#          'Larsen…\n',
#  'genre': ['/', 'Comédie'],
#  'img': '...',
#  'release': '10 juillet 2019',
#  'score': '5,0',
#  'time': '\n1h 12min\n',
#  'title': "La Ruée vers l'or"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Gérard Oury',
#  'desc': '\n'
#          'En 1942, un avion anglais est abattu par les Allemands au-dessus de '
#          'Paris. Les trois pilotes sautent en parachute et atterrissent dans '
#          'différents endroits de la capitale.\xa0\n',
#  'genre': ['/', 'Comédie'],
#  'img': '...',
#  'release': '13 juillet 2016',
#  'score': '3,8',
#  'time': '\n2h 12min\n',
#  'title': 'La Grande Vadrouille'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Stanley Kubrick',
#  'desc': '\n'
#          'Dans un immense hôtel, vide de clients et noyé sous la neige, un '
#          "écrivain en panne d'inspiration sombre peu à peu dans une folie "
#          'meurtrière incontrôlable.\n',
#  'genre': ['/', 'Epouvante-horreur', 'Thriller'],
#  'img': '...',
#  'release': '22 mai 2019',
#  'score': '4,0',
#  'time': '\n2h 23min\n',
#  'title': 'Shining'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'James Cameron',
#  'desc': '\n'
#          'Southampton, 10 avril 1912. Le paquebot le plus grand et le plus '
#          'moderne du monde, réputé pour son insubmersibilité, le Titanic '
#          'appareille pour son premier voyage. Quatre jours plus tard, il '
#          'heurte un iceberg. A son bord, un artiste pauvre et une grande '
#          'bourgeoise tombent amoureux.\n',
#  'genre': ['/', 'Drame', 'Romance'],
#  'img': '...',
#  'release': '8 février 2023',
#  'score': '4,9',
#  'time': '\n3h 14min\n',
#  'title': 'Titanic'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Denis Villeneuve',
#  'desc': '\n'
#          'Dans la banlieue de Boston, deux fillettes de 6 ans, Anna et Joy, '
#          'ont disparu. Le détective Loki privilégie la thèse du kidnapping '
#          'suite au témoignage de Keller, le père d’Anna. Le suspect numéro 1 '
#          'est rapidement arrêté mais est relâché quelques jours plus tard '
#          'faute de preuve, entrainant la fureur de Keller.\n',
#  'genre': ['/', 'Thriller'],
#  'img': '...',
#  'release': None,
#  'score': '3,8',
#  'time': '\n2h 33min\n',
#  'title': 'Prisoners'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Max Ophüls',
#  'desc': '\n'
#          'Vienne 1900. Quelques heures avant l’aube et sur le point '
#          'd’affronter en duel un adversaire, un mari trompé, qu’il a '
#          'd’ailleurs l’intention de fuir, Stefan Brand, ex-pianiste célèbre, '
#          'homme à femmes, reçoit une longue missive d’une inconnue, Lisa '
#          'Berndle.\n',
#  'genre': ['/', 'Drame', 'Romance'],
#  'img': '...',
#  'release': '9 février 2022',
#  'score': '4,3',
#  'time': '\n1h 27min\n',
#  'title': "Lettre d'une inconnue"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': None,
#  'desc': '\n'
#          'Le publiciste Roger Tornhill se retrouve par erreur dans la peau '
#          "d'un espion. Pris entre une mystérieuse organisation qui cherche à "
#          'le supprimer et la police qui le poursuit, Tornhill est dans une '
#          'situation bien inconfortable.\n',
#  'genre': ['/', 'Policier', 'Aventure', 'Espionnage'],
#  'img': '...',
#  'release': None,
#  'score': '4,6',
#  'time': '\n2h 16min\n',
#  'title': 'La Mort aux trousses'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=9>
# {'author': 'Quentin Tarantino',
#  'desc': '\n'
#          "Parce qu'un hold-up a échoué lamentablement, des truands vont "
#          "s'entretuer, persuadés que l'un des leurs est un traître qui les a "
#          'vendus à la police.\n',
#  'genre': ['/', 'Policier', 'Thriller'],
#  'img': '...',
#  'release': '12 août 2009',
#  'score': '4,5',
#  'time': '\n1h 39min\n',
#  'title': 'Reservoir Dogs'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Steven Spielberg',
#  'desc': '\n'
#          'Alors que les forces alliées débarquent à Omaha Beach, Miller doit '
#          'conduire son escouade derrière les lignes ennemies pour une mission '
#          'particulièrement dangereuse : trouver et ramener sain et sauf le '
#          'simple soldat James Ryan, dont les trois frères sont morts au combat '
#          "en l'espace de trois jours. Pendant que l'escouade progresse en "
#          'territoire ...\n',
#  'genre': ['/', 'Guerre', 'Drame'],
#  'img': '...',
#  'release': None,
#  'score': '3,0',
#  'time': '\n2h 43min\n',
#  'title': 'Il faut sauver le soldat Ryan'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Ridley Scott',
#  'desc': '\n'
#          'Le vaisseau Nostromo et son équipage rentrent sur Terre avec une '
#          "cargaison de minerai. Mais lors d'un arrêt forcé sur une planète "
#          "déserte, l'officier Kane se fait agresser par une forme de vie "
#          'inconnue, une arachnide qui étouffe son visage...\n',
#  'genre': ['/', 'Science Fiction', 'Epouvante-horreur'],
#  'img': '...',
#  'release': '12 novembre 2003',
#  'score': '4,4',
#  'time': '\n1h 56min\n',
#  'title': 'Alien, le huitième passager'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Lana Wachowski',
#  'desc': '\n'
#          "Programmeur anonyme, Thomas Anderson est aussi l'un des pirates les "
#          'plus recherchés du cyber-space. Il est contacté par un certain '
#          'Morpheus. Ensemble, ils se lancent dans une lutte sans retour contre '
#          'la Matrice et ses terribles agents...\n',
#  'genre': ['/', 'Action', 'Science Fiction'],
#  'img': '...',
#  'release': None,
#  'score': '3,4',
#  'time': '\n2h 15min\n',
#  'title': 'Matrix'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Wilson Yip',
#  'desc': '\n'
#          'Film biographique sur la vie de Ip Man, pionnier du Wing Chun et '
#          'maitre de Bruce Lee.\n',
#  'genre': ['/', 'Arts Martiaux', 'Action', 'Biopic'],
#  'img': '...',
#  'release': None,
#  'score': '4,4',
#  'time': '\n1h 45min\n',
#  'title': 'Ip Man'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': None,
#  'desc': '\n'
#          "1936. L'aventurier Indiana Jones est mandaté pour mettre la main sur "
#          'le médaillon de Râ, qui serait le premier pas sur le chemin de '
#          "l'Arche d'Alliance, celle-là même où Moïse conserva les Dix "
#          "Commandements. Une pièce dont Hitler cherche aussi à s'emparer.\n",
#  'genre': ['/', 'Aventure', 'Action'],
#  'img': '...',
#  'release': None,
#  'score': '4,6',
#  'time': '\n1h 56min\n',
#  'title': "Les Aventuriers de l'Arche perdue"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Martin Scorsese',
#  'desc': '\n'
#          "1954. Teddy Daniels et Chuck Aule enquêtent sur la disparition d'une "
#          "patiente échappée d'un hôpital psychiatrique à sécurité maximale. "
#          "L'hôpital en question est basé sur Shutter Island, une île située à "
#          'environ une heure au large de Boston.\n',
#  'genre': ['/', 'Thriller'],
#  'img': '...',
#  'release': None,
#  'score': '3,8',
#  'time': '\n2h 17min\n',
#  'title': 'Shutter Island'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Alfred Hitchcock',
#  'desc': '\n'
#          'Un reporter immobilisé par un plâtre observe de sa fenêtre les '
#          "allées et venues de ses voisins. Le comportement bizarre d'un "
#          "représentant de commerce l'intrigue à un point tel qu'il le croit "
#          'meurtrier de sa femme. Fantasme ou réalité ?\n',
#  'genre': ['/', 'Policier', 'Thriller'],
#  'img': '...',
#  'release': '22 octobre 2008',
#  'score': '3,9',
#  'time': '\n1h 50min\n',
#  'title': 'Fenêtre sur cour'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=7>
# {'author': 'Henri-Georges Clouzot',
#  'desc': '\n'
#          'Dominique Marceau, une jeune fille provocante, est accusée du '
#          'meurtre de son ancien amant Gilbert Tellier. Au cours du procès, '
#          "l'histoire de sa relation avec la victime est reconstituée.\n",
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': '8 novembre 2017',
#  'score': '4,9',
#  'time': '\n2h 07min\n',
#  'title': 'La Vérité'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Charles Chaplin',
#  'desc': '\n'
#          'Dans le ghetto juif vit un petit barbier qui ressemble énormément à '
#          'Adenoid Hynkel, le dictateur de Tomania qui a décidé l’extermination '
#          'du peuple juif. Au cours d’une rafle, le barbier est arrêté en '
#          'compagnie de Schultz, un farouche adversaire d’Hynkel...\n',
#  'genre': ['/', 'Comédie'],
#  'img': '...',
#  'release': '10 juillet 2019',
#  'score': '5,0',
#  'time': '\n2h 05min\n',
#  'title': 'Le Dictateur'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Martin Scorsese',
#  'desc': '\n'
#          "Depuis sa plus tendre enfance, Henry Hill, né d'un père irlandais et "
#          "d'une mère sicilienne, veut devenir gangster et appartenir à la "
#          'Mafia. Adolescent dans les années cinquante, il commence par '
#          'travailler pour le compte de Paul Cicero...\n',
#  'genre': ['/', 'Drame', 'Policier'],
#  'img': '...',
#  'release': '7 juin 2023',
#  'score': '5,0',
#  'time': '\n2h 25min\n',
#  'title': 'Les Affranchis'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Bong Joon Ho',
#  'desc': '\n'
#          'Toute la famille de Ki-taek est au chômage, et s’intéresse fortement '
#          'au train de vie de la richissime famille Park. Un jour, leur fils '
#          'réussit à se faire recommander pour donner des cours particuliers '
#          'd’anglais chez les Park. C’est le début d’un engrenage '
#          'incontrôlable...\n',
#  'genre': ['/', 'Thriller'],
#  'img': '...',
#  'release': None,
#  'score': '4,8',
#  'time': '\n2h 12min\n',
#  'title': 'Parasite'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Makoto Shinkai',
#  'desc': '\n'
#          'Mitsuha, adolescente coincée dans une famille traditionnelle, rêve '
#          'de quitter ses montagnes natales pour découvrir la vie trépidante de '
#          'Tokyo. Elle est loin d’imaginer pouvoir vivre l’aventure urbaine '
#          'dans la peau de… Taki, un jeune lycéen vivant à Tokyo, occupé entre '
#          'son petit boulot dans un restaurant italien et ses nombreux amis.\n',
#  'genre': ['/', 'Animation', 'Fantastique'],
#  'img': '...',
#  'release': None,
#  'score': '4,0',
#  'time': '\n1h 50min\n',
#  'title': 'Your Name'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': None,
#  'desc': '\n'
#          'Le narrateur, vit seul, travaille seul, dort seul, comme beaucoup '
#          "d'autres personnes seules qui connaissent la misère morale et "
#          "sexuelle. C'est pourquoi il va devenir membre du Fight club, un lieu "
#          'clandestin dirigé par Tyler Durden, anarchiste entre gourou et '
#          'philosophe.\n',
#  'genre': ['/', 'Thriller', 'Drame'],
#  'img': '...',
#  'release': '15 mai 2019',
#  'score': '2,7',
#  'time': '\n2h 19min\n',
#  'title': 'Fight Club'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Lee Unkrich',
#  'desc': '\n'
#          'Depuis déjà plusieurs générations, la musique est bannie dans la '
#          'famille de Miguel. Un vrai déchirement pour le jeune garçon dont le '
#          'rêve ultime est de devenir un musicien aussi accompli que son idole, '
#          'Ernesto de la Cruz.\xa0\n',
#  'genre': ['/', 'Animation', 'Fantastique', 'Famille'],
#  'img': '...',
#  'release': None,
#  'score': '4,1',
#  'time': '\n1h 45min\n',
#  'title': 'Coco'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Francis Ford Coppola',
#  'desc': '\n'
#          'Depuis la mort de Don Vito Corleone, son fils Michael règne sur la '
#          'famille. Amené à négocier avec la mafia juive, il perd le soutien de '
#          'son lieutenant Frankie Pentageli. Echappant de justesse à un '
#          'attentat, Michael tente de retrouver le coupable...\n',
#  'genre': ['/', 'Policier', 'Drame'],
#  'img': '...',
#  'release': '18 septembre 2013',
#  'score': '4,7',
#  'time': '\n3h 20min\n',
#  'title': 'Le Parrain, 2e partie'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=3>
# {'author': 'Christopher Nolan',
#  'desc': '\n'
#          'Au lieu de subtiliser un rêve, un voleur expérimenté et son équipe '
#          "doivent faire l'inverse : implanter une idée dans l'esprit d'un "
#          "individu. S'ils y parviennent, il pourrait s'agir du crime parfait "
#          '...\n',
#  'genre': ['/', 'Science Fiction', 'Thriller'],
#  'img': '...',
#  'release': '7 juin 2023',
#  'score': '4,1',
#  'time': '\n2h 28min\n',
#  'title': 'Inception'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Mamoru Hosoda',
#  'desc': '\n'
#          'Hana et ses deux enfants, Ame et Yuki, vivent discrètement dans un '
#          'coin tranquille de la ville. Leur vie est simple et joyeuse, mais '
#          'ils cachent un secret : leur père est un homme-loup. Quand celui-ci '
#          'disparaît brutalement, Hana décide de quitter la ville pour élever '
#          'ses enfants...\n',
#  'genre': ['/', 'Animation', 'Fantastique'],
#  'img': 'https://fr.web.img3.acsta.net/c_310_420/medias/nmedia/18/90/30/39/20090421.jpg',
#  'release': None,
#  'score': '4,1',
#  'time': '\n1h 57min\n',
#  'title': 'Les Enfants Loups, Ame & Yuki'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Jeanne Herry',
#  'desc': '\n'
#          'Depuis 2014, en France, la Justice Restaurative propose à des '
#          'personnes victimes et auteurs d’infraction de dialoguer dans des '
#          'dispositifs sécurisés, encadrés par des professionnels et des '
#          'bénévoles comme Judith, Fanny ou Michel.\n',
#  'genre': ['/', 'Drame'],
#  'img': 'https://fr.web.img6.acsta.net/c_310_420/o_club-allocine-310x420.png_0_se/pictures/23/02/16/11/33/5603857.jpg',
#  'release': None,
#  'score': '4,1',
#  'time': '\n1h 58min\n',
#  'title': 'Je verrai toujours vos visages'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Peter Farrelly',
#  'desc': '\n'
#          'En 1962, alors que règne la ségrégation, Tony Lip, un videur '
#          'italo-américain du Bronx, est engagé pour conduire et protéger le Dr '
#          'Don Shirley, un pianiste noir de renommée mondiale, lors d’une '
#          'tournée de concerts.\n',
#  'genre': ['/', 'Drame', 'Biopic'],
#  'img': 'https://fr.web.img6.acsta.net/c_310_420/o_club-allocine-310x420.png_0_se/pictures/19/02/25/17/06/0818764.jpg',
#  'release': None,
#  'score': '4,0',
#  'time': '\n2h 10min\n',
#  'title': 'Green Book : Sur les routes du sud'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Après être arrivé en 1955 à bord d'une DeLorean convertie en machine "
#          "à remonter le temps, Marty McFly fonce pour s'assurer que ses futurs "
#          'parents tombent amoureux.\n',
#  'genre': ['/', 'Science Fiction', 'Aventure', 'Comédie'],
#  'img': 'https://fr.web.img6.acsta.net/c_310_420/pictures/22/07/22/15/00/2862661.jpg',
#  'release': None,
#  'score': '3,6',
#  'time': '\n1h 56min\n',
#  'title': 'Retour vers le futur'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Roberto Benigni',
#  'desc': '\n'
#          "En 1938, Guido, jeune homme plein de gaieté, rêve d'ouvrir une "
#          "librairie, malgré les tracasseries de l'administration fasciste. Il "
#          'tombe amoureux de Dora, institutrice étouffée par le conformisme '
#          "familial et l'enlève le jour de ses fiançailles avec un bureaucrate "
#          'du régime. Cinq ans plus tard, Guido et Dora ont un fils: Giosue. '
#          'Mais les ...\n',
#  'genre': ['/', 'Comédie dramatique', 'Drame', 'Comédie'],
#  'img': '...',
#  'release': None,
#  'score': '3,7',
#  'time': '\n1h 57min\n',
#  'title': 'La Vie est belle'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Stanley Kubrick',
#  'desc': '\n'
#          "Pendant la guerre du Viêt Nam, la préparation et l'entrainement d'un "
#          "groupe de jeunes marines, jusqu'au terrible baptême du feu et la "
#          'sanglante offensive du Tết à Huế, en 1968.\n',
#  'genre': ['/', 'Guerre', 'Drame'],
#  'img': 'https://fr.web.img3.acsta.net/c_310_420/medias/nmedia/18/65/57/12/19254508.jpg',
#  'release': None,
#  'score': '4,8',
#  'time': '\n1h 56min\n',
#  'title': 'Full Metal Jacket'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Isao Takahata',
#  'desc': '\n'
#          'Kaguya, « la princesse lumineuse », est un petit être découvert dans '
#          'la tige d’un bambou par un vieux paysan. La considérant comme un don '
#          'du ciel, il l’élève avec sa femme, et très vite l’enfant devient une '
#          'magnifique jeune fille. De la campagne lointaine jusqu’à la grande '
#          'capitale, sa fascinante beauté suscitera l’engouement auprès de tous '
#          'ceux qui la rencontrent et elle sera convoitée par cinq nobles '
#          'princes qui devront relever d’impossibles défis dans l’espoir '
#          'd’obtenir sa main. Mais le temps venu, elle devra affronter son '
#          'destin…\n',
#  'genre': ['/', 'Animation', 'Drame', 'Fantastique'],
#  'img': 'https://fr.web.img4.acsta.net/c_310_420/pictures/14/04/25/12/27/122290.jpg',
#  'release': None,
#  'score': '4,5',
#  'time': '\n2h 17min\n',
#  'title': 'Le Conte de la princesse Kaguya'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': 'Sergio Leone',
#  'desc': '\n'
#          'Un mystérieux desperado pourchasse sans relâche un dangereux '
#          'criminel.\n',
#  'genre': ['/', 'Western'],
#  'img': 'https://fr.web.img3.acsta.net/c_310_420/pictures/16/07/19/17/05/434841.jpg',
#  'release': '10 octobre 2018',
#  'score': '4,0',
#  'time': '\n2h 55min\n',
#  'title': "Il était une fois dans l'Ouest"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': 'Quentin Tarantino',
#  'desc': '\n'
#          "L'odyssée sanglante et burlesque de petits malfrats dans la jungle "
#          "de Hollywood à travers trois histoires qui s'entremêlent.\n",
#  'genre': ['/', 'Policier', 'Drame'],
#  'img': 'https://fr.web.img2.acsta.net/c_310_420/medias/nmedia/18/36/02/52/18846059.jpg',
#  'release': None,
#  'score': '4,4',
#  'time': '\n2h 29min\n',
#  'title': 'Pulp Fiction'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Michael Cimino',
#  'desc': '\n'
#          "Entre Amérique et Viêtnam, le parcours et le destin tragiques d'une "
#          "bande d'amis soudés, confrontés aux horreurs et aux injustices de la "
#          'guerre.\n',
#  'genre': ['/', 'Drame', 'Guerre'],
#  'img': '...',
#  'release': '25 juillet 2018',
#  'score': '4,7',
#  'time': '\n3h 03min\n',
#  'title': "Voyage au bout de l'enfer"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Mel Gibson',
#  'desc': '\n'
#          '1945, alors que la guerre dans le Pacifique fait rage et que les '
#          'forces américaines mènent l’une des batailles les plus acharnées du '
#          'conflit sur l’île d’Okinawa, un soldat s’est distingué. Fidèle à ses '
#          'convictions et armé de son seul courage, il a sauvé la vie de '
#          'dizaines de soldats blessés.\n',
#  'genre': ['/', 'Guerre', 'Drame', 'Biopic'],
#  'img': '...',
#  'release': None,
#  'score': '3,0',
#  'time': '\n2h 20min\n',
#  'title': 'Tu ne tueras point'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Kenji Mizoguchi',
#  'desc': '\n'
#          'XIe siècle. Un gouverneur de province est exilé pour avoir pris le '
#          'parti des paysans contre l’avis d’un chef militaire. Contraints de '
#          'reprendre la route de son village natal, sa femme Nakagimi et ses '
#          'enfants Anju et Zushio sont kidnappés par des bandits de grand '
#          'chemin...\n',
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': '31 juillet 2019',
#  'score': '5,0',
#  'time': '\n2h 04min\n',
#  'title': "L'Intendant Sansho"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Masaki Kobayashi',
#  'desc': '\n'
#          'Japon, 17ème siècle. Le samouraï Tsugumo vient se présenter à la '
#          'demeure du clan Lyi. Il veut se faire Hara-kiri. Mais le maître des '
#          "lieux essaie bien de l'en dissuader. Tsugumo livre alors dans un "
#          'récit les vraies raisons de son geste...\n',
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': '13 août 2008',
#  'score': '4,6',
#  'time': '\n2h 13min\n',
#  'title': 'Harakiri'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Roman Polanski',
#  'desc': '\n'
#          'Durant la Seconde Guerre mondiale, Wladyslaw Szpilman, un pianiste '
#          'juif polonais, est interné dans le ghetto de Varsovie dont il '
#          'partage les souffrances, les humiliations et les luttes héroïques. '
#          "Un officier allemand l'aide et lui permet de survivre.\n",
#  'genre': ['/', 'Drame', 'Historique'],
#  'img': '...',
#  'release': None,
#  'score': '4,1',
#  'time': '\n2h 28min\n',
#  'title': 'Le Pianiste'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Hayao Miyazaki',
#  'desc': '\n'
#          'Japon, XVe siècle. Jadis protégée par des animaux géants, la forêt '
#          "se dépeuple à cause de l'homme. Blessé par un sanglier rendu fou par "
#          'les démons, le jeune guerrier Ashitaka quitte les siens et part à la '
#          'recherche du dieu-cerf qui seul pourra défaire le sortilège qui lui '
#          'gangrène le bras. Au cours de son voyage, Ashitaka rencontre Lady '
#          'Eboshi, à la tête d’une communauté de forgerons, qui doit se '
#          'défendre contre ceux qui lui reprochent de détruire la forêt pour '
#          'alimenter ses forges. Parmi ses pires ennemis se trouve San, une '
#          'jeune fille sauvage élevée par des loups, aussi appelée "Princesse '
#          'Mononoké", la princesse des spectres...\n',
#  'genre': ['/', 'Animation', 'Aventure', 'Fantastique'],
#  'img': '...',
#  'release': None,
#  'score': '4,8',
#  'time': '\n2h 15min\n',
#  'title': 'Princesse Mononoké'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Steven Spielberg',
#  'desc': '\n'
#          "L'archéologue aventurier Indiana Jones se retrouve aux prises avec "
#          'un maléfique milliardaire. Aux côtés de la cupide Elsa et de son '
#          'père, il part à la recherche du Graal.\n',
#  'genre': ['/', 'Aventure', 'Action'],
#  'img': '...',
#  'release': None,
#  'score': '4,4',
#  'time': '\n2h 07min\n',
#  'title': 'Indiana Jones et la Dernière Croisade'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=6>
# {'author': 'Bob Persichetti',
#  'desc': '\n'
#          'SPIDER-MAN : NEW GENERATION présente Miles Morales, un adolescent '
#          'vivant à Brooklyn, et révèle les possibilités illimitées du '
#          'Spider-Verse, un univers où plus d’un peut porter le masque…\n',
#  'genre': ['/', 'Animation', 'Action', 'Famille'],
#  'img': '...',
#  'release': None,
#  'score': '4,2',
#  'time': '\n1h 57min\n',
#  'title': 'Spider-Man : New Generation'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Charles Chaplin',
#  'desc': '\n'
#          'Charlot est ouvrier dans une immense usine. Il resserre '
#          'quotidiennement des boulons. Mais les machines, le travail à la '
#          'chaîne le rendent malade, il abandonne son poste et recueille une '
#          'orpheline…\n',
#  'genre': ['/', 'Romance', 'Comédie dramatique', 'Comédie'],
#  'img': '...',
#  'release': '10 juillet 2019',
#  'score': '4,6',
#  'time': '\n1h 27min\n',
#  'title': 'Les Temps modernes'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Joaquim Dos Santos',
#  'desc': '\n'
#          'Après avoir retrouvé Gwen Stacy, Spider-Man, le sympathique héros '
#          'originaire de Brooklyn, est catapulté à travers le Multivers, où il '
#          "rencontre une équipe de Spider-Héros chargée d'en protéger "
#          "l'existence.\n",
#  'genre': ['/', 'Animation', 'Action', 'Fantastique'],
#  'img': '...',
#  'release': None,
#  'score': '4,1',
#  'time': '\n2h 21min\n',
#  'title': 'Spider-Man : Across The Spider-Verse'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Bryan Singer',
#  'desc': '\n'
#          'Suite à une mystérieuse dénonciation, cinq criminels se retrouvent '
#          'en garde à vue. Plus tard, engagés sur un coup par le génie du crime '
#          'Keyser Söze, les cinq hommes sont pris au piège d’une diabolique '
#          'machination…\n',
#  'genre': ['/', 'Policier', 'Thriller'],
#  'img': '...',
#  'release': '18 juillet 2001',
#  'score': '4,6',
#  'time': '\n1h 46min\n',
#  'title': 'Usual Suspects'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': None,
#  'desc': '\n'
#          'Lâchée par son amant, une jeune femme abandonne son enfant. Charlot '
#          'le vagabond le recueille. Mais les services sociaux s’en mêlent...\n',
#  'genre': ['/', 'Comédie'],
#  'img': '...',
#  'release': '10 juillet 2019',
#  'score': '4,0',
#  'time': '\n0h 52min\n',
#  'title': 'Le Kid'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Isao Takahata',
#  'desc': '\n'
#          'Japon, été 1945. Après le bombardement de Kobé, Seita, un adolescent '
#          'de quatorze ans et sa petite soeur de quatre ans, Setsuko, '
#          "orphelins, vont s'installer chez leur tante à quelques dizaines de "
#          "kilomètres de chez eux. Celle-ci leur fait comprendre qu'ils sont "
#          'une gêne pour la famille et doivent mériter leur riz quotidien. '
#          'Seita décide de ...\n',
#  'genre': ['/', 'Animation', 'Drame', 'Guerre'],
#  'img': '...',
#  'release': None,
#  'score': '4,0',
#  'time': '\n1h 30min\n',
#  'title': 'Le Tombeau des lucioles'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Damien Chazelle',
#  'desc': '\n'
#          'Andrew, 19 ans, rêve de devenir l’un des meilleurs batteurs de\xa0'
#          'jazz de sa génération. Mais la concurrence est rude au\xa0'
#          'conservatoire de Manhattan où il s’entraîne avec acharnement...\n',
#  'genre': ['/', 'Drame', 'Musical'],
#  'img': '...',
#  'release': None,
#  'score': '4,1',
#  'time': '\n1h 47min\n',
#  'title': 'Whiplash'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=4>
# {'author': 'Jonathan Demme',
#  'desc': '\n'
#          'Clarice Starling, jeune stagiaire du FBI, est désignée pour enquêter '
#          'sur une série de meurtres épouvantables commis dans le Middle West '
#          'par un tueur de femmes psychopathe connu sous le nom de Buffalo '
#          'Bill.\n',
#  'genre': ['/', 'Thriller', 'Drame', 'Policier'],
#  'img': '...',
#  'release': '7 octobre 2020',
#  'score': '4,8',
#  'time': '\n1h 58min\n',
#  'title': 'Le Silence des agneaux'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Jacques Becker',
#  'desc': '\n'
#          "Cinq prisonniers, enfermés à La Santé, vont tenter de s'évader en "
#          'creusant un tunnel.\n',
#  'genre': ['/', 'Drame', 'Thriller'],
#  'img': '...',
#  'release': '19 avril 2017',
#  'score': '4,4',
#  'time': '\n2h 12min\n',
#  'title': 'Le Trou'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': None,
#  'desc': '\n'
#          "Grandeur et décadence d'un hobereau au XVIIIe siècle, d'abord engagé "
#          "dans l'armée britannique, puis compagnon d'une comtesse, jeune veuve "
#          'éplorée.\n',
#  'genre': ['/', 'Aventure', 'Drame'],
#  'img': '...',
#  'release': '19 décembre 2007',
#  'score': '5,0',
#  'time': '\n3h 07min\n',
#  'title': 'Barry Lyndon'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'David Lynch',
#  'desc': '\n'
#          'Londres, 1884. Le chirurgien Frederick Treves découvre un homme '
#          'complètement défiguré et difforme, devenu une attraction de foire. '
#          'John Merrick, " le monstre ", doit son nom de Elephant Man au '
#          'terrible accident que subit sa mère.\xa0\n',
#  'genre': ['/', 'Drame', 'Biopic'],
#  'img': '...',
#  'release': '22 juin 2020',
#  'score': '4,8',
#  'time': '\n2h 05min\n',
#  'title': 'Elephant Man'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Xavier Dolan',
#  'desc': '\n'
#          'Une veuve mono-parentale hérite de la garde de son fils, un '
#          'adolescent profondément turbulent. Ensemble, ils tentent de joindre '
#          'les deux bouts, notamment grâce à l’aide inattendue de la '
#          'mystérieuse voisine d’en face, Kyla.\n',
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': None,
#  'score': '4,3',
#  'time': '\n2h 19min\n',
#  'title': 'Mommy'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Lee Unkrich',
#  'desc': '\n'
#          "Woody le cowboy, Buzz l'Eclair et les autres jouets se retrouvent "
#          "confrontés à ce qui devait bien arriver un jour : le départ d'Andy "
#          "pour l'université...\n",
#  'genre': ['/', 'Animation', 'Aventure', 'Fantastique'],
#  'img': '...',
#  'release': None,
#  'score': '4,7',
#  'time': '\n1h 40min\n',
#  'title': 'Toy Story 3'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Tim Burton',
#  'desc': '\n'
#          "Edward Scissorhands n'est pas un garcon ordinaire. Création d'un "
#          'inventeur, il a recu un coeur pour aimer, un cerveau pour '
#          "comprendre. Mais son concepteur est mort avant d'avoir pu terminer "
#          'son oeuvre...\n',
#  'genre': ['/', 'Fantastique', 'Romance', 'Drame'],
#  'img': '...',
#  'release': None,
#  'score': '4,4',
#  'time': '\n1h 45min\n',
#  'title': "Edward aux mains d'argent"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Kenji Mizoguchi',
#  'desc': '\n'
#          'Fille d’une bonne famille aristocratique, introduite à la cour '
#          'impériale de Kyoto, O-Harru tombe amoureuse d’un homme d’une classe '
#          'sociale inférieure. Dès lors, sa vie ne sera que tristesse et '
#          'humiliation. Ce magnifique mélodrame est un portrait de femme '
#          'bouleversant.\n',
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': '16 mars 2016',
#  'score': '5,0',
#  'time': '\n2h 16min\n',
#  'title': "La Vie d'O'Haru, Femme Galante"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=8>
# {'author': 'Andrew Stanton',
#  'desc': '\n'
#          "L'histoire d'un petit robot nommé WALL•E, à la recherche du grand "
#          "amour sur Terre... et dans l'espace !\n",
#  'genre': ['/', 'Animation', 'Aventure', 'Science Fiction'],
#  'img': '...',
#  'release': None,
#  'score': '4,6',
#  'time': '\n1h 37min\n',
#  'title': 'Wall-E'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': None,
#  'desc': '\n'
#          'Pendant la Guerre de Sécession, Tuco, Joe et Setenza, trois hommes '
#          "préférant s'intéresser à leur profit personnel, se lancent à la "
#          "recherche d'un coffre contenant 200 000 dollars en pièces d'or volés "
#          "à l'armée sudiste. Chacun a besoin de l'autre...\n",
#  'genre': ['/', 'Western'],
#  'img': '...',
#  'release': '5 novembre 2014',
#  'score': '4,1',
#  'time': '\n3h 00min\n',
#  'title': 'Le Bon, la brute et le truand'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': None,
#  'desc': '\n'
#          'Il était une fois deux truands juifs, Max et Noodles, liés par un '
#          "pacte d'éternelle amitié. Débutant au début du siècle par de "
#          'fructueux trafics dans le ghetto de New York, ils voient leurs '
#          'chemins se séparer, lorsque Noodles se retrouve durant quelques '
#          'années derrière les barreaux, puis se recouper en pleine période de '
#          "prohibition, dans les années vingt. Jusqu'au jour où la trahison les "
#          'sépare à nouveau.\n',
#  'genre': ['/', 'Drame', 'Policier'],
#  'img': '...',
#  'release': '6 mai 2015',
#  'score': '4,9',
#  'time': '\n3h 49min\n',
#  'title': 'Il était une fois en Amérique'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': 'Christopher Nolan',
#  'desc': '\n'
#          'Le film raconte les aventures d’un groupe d’explorateurs qui '
#          'utilisent une faille récemment découverte dans l’espace-temps afin '
#          'de repousser les limites humaines et partir à la conquête des '
#          'distances astronomiques dans un voyage interstellaire.\xa0\n',
#  'genre': ['/', 'Science Fiction', 'Drame'],
#  'img': '...',
#  'release': None,
#  'score': '3,8',
#  'time': '\n2h 49min\n',
#  'title': 'Interstellar'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': 'Ridley Scott',
#  'desc': '\n'
#          "Le général romain Maximus est le plus fidèle soutien de l'empereur "
#          "Marc Aurèle, qu'il a conduit de victoire en victoire avec une "
#          'bravoure et un dévouement exemplaires. Jaloux du prestige de '
#          "Maximus, et plus encore de l'amour que lui voue l'empereur, le fils "
#          "de MarcAurèle, Commode, s'arroge brutalement le pouvoir, puis "
#          "ordonne l'arrestation du ...\n",
#  'genre': ['/', 'Action', 'Aventure', 'Historique'],
#  'img': '...',
#  'release': None,
#  'score': '4,3',
#  'time': '\n2h 35min\n',
#  'title': 'Gladiator'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': None,
#  'desc': '\n'
#          "Un chasseur de primes et un esclave noir s'associent pour retrouver "
#          'la femme de ce dernier, retenue en esclavage par le propriétaire '
#          "d'une plantation.\n",
#  'genre': ['/', 'Western'],
#  'img': '...',
#  'release': None,
#  'score': '4,6',
#  'time': '\n2h 44min\n',
#  'title': 'Django Unchained'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': 'Peter Jackson',
#  'desc': '\n'
#          "Frodon le Hobbit hérite de l'Anneau Unique, un instrument de pouvoir "
#          'absolu qui permettrait à Sauron, le Seigneur des ténèbres, de régner '
#          'sur la Terre du Milieu. Commence alors un vaste périple visant à la '
#          "destruction de l'objet.\n",
#  'genre': ['/', 'Fantastique', 'Aventure'],
#  'img': '...',
#  'release': None,
#  'score': '3,7',
#  'time': '\n2h 58min\n',
#  'title': "Le Seigneur des anneaux : la communauté de l'anneau"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': None,
#  'desc': '\n'
#          'Frodon Sacquet, le Hobbit, doit braver de terribles dangers pour '
#          "tenter de détruire l'Anneau Unique, convoité par Sauron, le Seigneur "
#          'des ténèbres. De leur côté, Gimli, Legolas et Aragorn doivent sauver '
#          'Pippin et Merry, capturés par les Orques...\n',
#  'genre': ['/', 'Aventure', 'Fantastique'],
#  'img': '...',
#  'release': None,
#  'score': '4,0',
#  'time': '\n2h 59min\n',
#  'title': 'Le Seigneur des anneaux : les deux tours'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/?page=2>
# {'author': None,
#  'desc': '\n'
#          'Walt Kowalski est un ancien de la guerre de Corée, un homme '
#          'inflexible, amer et pétri de préjugés surannés. Hormis sa chienne '
#          "Daisy, il ne fait confiance qu'à son M-1, toujours propre, toujours "
#          "prêt à l'usage...\n",
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': '7 juin 2023',
#  'score': '4,7',
#  'time': '\n1h 56min\n',
#  'title': 'Gran Torino'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Robert Zemeckis',
#  'desc': '\n'
#          "Quelques décennies d'histoire américaine, des années 1940 à la fin "
#          "du XXème siècle, à travers le regard et l'étrange odyssée d'un homme "
#          'simple et pur, Forrest Gump.\n',
#  'genre': ['/', 'Romance', 'Drame', 'Comédie'],
#  'img': 'https://fr.web.img2.acsta.net/c_310_420/pictures/15/10/13/15/12/514297.jpg',
#  'release': '28 octobre 2015',
#  'score': '2,6',
#  'time': '\n2h 20min\n',
#  'title': 'Forrest Gump'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Steven Spielberg',
#  'desc': '\n'
#          "Evocation des années de guerre d'Oskar Schindler, industriel "
#          'autrichien rentré à Cracovie en 1939 avec les troupes allemandes. Il '
#          'va, tout au long de la guerre, protéger des juifs en les faisant '
#          'travailler dans sa fabrique.\n',
#  'genre': ['/', 'Drame', 'Historique', 'Biopic'],
#  'img': 'https://fr.web.img4.acsta.net/c_310_420/pictures/19/03/14/10/37/5927961.jpg',
#  'release': '13 mars 2019',
#  'score': '4,2',
#  'time': '\n3h 15min\n',
#  'title': 'La Liste de Schindler'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Frank Darabont',
#  'desc': '\n'
#          'Paul Edgecomb, Gardien-chef du pénitencier de Cold Mountain en 1935, '
#          'était chargé de veiller au bon déroulement des exécutions capitales. '
#          'Parmi les prisonniers se trouvait un colosse du nom de John '
#          'Coffey...\n',
#  'genre': ['/', 'Fantastique', 'Drame', 'Policier'],
#  'img': '...',
#  'release': None,
#  'score': '2,8',
#  'time': '\n3h 09min\n',
#  'title': 'La Ligne verte'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Sidney Lumet',
#  'desc': '\n'
#          "Lors d'un procès, un juré émet l'hypothèse que l'homme qu'il doit "
#          "juger n'est peut-être pas coupable. Il va tenter de convaincre les "
#          'onze autres jurés.\n',
#  'genre': ['/', 'Drame', 'Judiciaire'],
#  'img': '...',
#  'release': '25 juillet 2007',
#  'score': '5,0',
#  'time': '\n1h 35min\n',
#  'title': '12 hommes en colère'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Francis Ford Coppola',
#  'desc': '\n'
#          'En 1945, à New York, les Corleone sont une des cinq familles de la '
#          'mafia. Don Vito Corleone marie sa fille à un bookmaker. Sollozzo, '
#          '"parrain" de la famille Tattaglia, propose à Don Vito une '
#          'association dans le trafic de drogue...\n',
#  'genre': ['/', 'Policier', 'Drame'],
#  'img': '...',
#  'release': '23 février 2022',
#  'score': '4,6',
#  'time': '\n2h 55min\n',
#  'title': 'Le Parrain'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': None,
#  'desc': '\n'
#          'Condamné à perpétuité pour le meurtre de sa femme et de son amant, '
#          "un banquier s'accroche à l'espoir et se lie d'amitié avec un autre "
#          'détenu pour survivre en prison.\n',
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': None,
#  'score': '3,2',
#  'time': '\n2h 22min\n',
#  'title': 'Les Evadés'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Peter Jackson',
#  'desc': '\n'
#          'Tandis que les ténèbres se répandent sur la Terre du Milieu, Aragorn '
#          "se révèle être l'héritier caché des rois antiques. Quant à Frodon, "
#          "toujours tenté par l'Anneau, il voyage à travers les contrées "
#          'ennemies, se reposant sur Sam et Gollum...\n',
#  'genre': ['/', 'Fantastique', 'Aventure'],
#  'img': '...',
#  'release': None,
#  'score': '3,8',
#  'time': '\n3h 21min\n',
#  'title': 'Le Seigneur des anneaux : le retour du roi'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Roger Allers',
#  'desc': '\n'
#          'Le long combat de Simba le lionceau pour accéder à son rang de roi '
#          'des animaux, après que le fourbe Scar, son oncle, a tué son père et '
#          'pris sa place.\n',
#  'genre': ['/', 'Animation', 'Aventure', 'Comédie musicale'],
#  'img': '...',
#  'release': '11 avril 2012',
#  'score': '3,4',
#  'time': '\n1h 29min\n',
#  'title': 'Le Roi Lion'}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Milos Forman',
#  'desc': '\n'
#          "Rebellion dans un hôpital psychiatrique à l'instigation d'un malade "
#          "qui se révolte contre la dureté d'une infirmière.\n",
#  'genre': ['/', 'Drame'],
#  'img': '...',
#  'release': '16 septembre 2009',
#  'score': '5,0',
#  'time': '\n2h 09min\n',
#  'title': "Vol au-dessus d'un nid de coucou"}
# 2024-01-04 10:50:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.allocine.fr/film/meilleurs/>
# {'author': 'Christopher Nolan',
#  'desc': '\n'
#          'Batman entreprend de démanteler les dernières organisations '
#          'criminelles de Gotham. Mais il se heurte bientôt à un nouveau génie '
#          'du crime qui répand la terreur et le chaos dans la ville : le '
#          'Joker...\n',
#  'genre': ['/', 'Action', 'Thriller'],
#  'img': '...',
#  'release': None,
#  'score': '4,0',
#  'time': '\n2h 32min\n',
#  'title': 'The Dark Knight, Le Chevalier Noir'}
# 2024-01-04 10:50:12 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-01-04 10:50:12 [scrapy.extensions.feedexport] INFO: Stored json feed (90 items) in: allocine.json
# 2024-01-04 10:50:12 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2599,
#  'downloader/request_count': 11,
#  'downloader/request_method_count/GET': 11,
#  'downloader/response_bytes': 534921,
#  'downloader/response_count': 11,
#  'downloader/response_status_count/200': 10,
#  'downloader/response_status_count/301': 1,
#  'elapsed_time_seconds': 3.975406,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 1, 4, 9, 50, 12, 997086, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 4214605,
#  'httpcompression/response_count': 10,
#  'item_scraped_count': 90,
#  'log_count/DEBUG': 104,
#  'log_count/INFO': 11,
#  'memusage/max': 64745472,
#  'memusage/startup': 64745472,
#  'response_received_count': 10,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 10,
#  'scheduler/dequeued/memory': 10,
#  'scheduler/enqueued': 10,
#  'scheduler/enqueued/memory': 10,
#  'start_time': datetime.datetime(2024, 1, 4, 9, 50, 9, 21680, tzinfo=datetime.timezone.utc)}
# 2024-01-04 10:50:12 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## 4.7 Importez la bibliothèque Pandas puis visualisez votre collecte de données

# %% [markdown]
# # Partie 2 - Cotations boursières du CAC40 - [Boursorama](https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC)
#
#
# <img src='data:image/png;base64,...'>
#
#
#
# L'objectif de cet exercice sera de collecter les données en temps réelle des actions du CAC40.
# Les données que nous collecterons serons :
#
# - le nom de l'indice boursier
# - le cours de l'action
# - la variation de l'action
# - la valeur la plus haute de la séance
# - la valeur la plus basse
# - la valeur d'ouverture
# - la date et l'heure de la collecte
#
#
# ## Lancez le projet scrapy
#
# Créez le projet scrapy nomé `boursorama` en utilisant le lien suivant `https://www.boursorama.com/bourse/actions/palmares/france/page-1`.
#
# Pour rappel la commande scrapy pour génére un nouveau spider est la suivante :
#
# `scrapy genspider nom_du_projet adresse_url`

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.11.0-py2.py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 5.1 MB/s eta 0:00:00
# Collecting Twisted<23.8.0,>=18.9.0 (from scrapy)
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 50.4 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (41.0.7)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.1.0-py3-none-any.whl (11 kB)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.8.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (23.3.0)
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-23.1.0-py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting zope.interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 21.1 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading Protego-0.3.0-py2.py3-none-any.whl (8.5 kB)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from scrapy) (67.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from scrapy) (23.2)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-5.1.1-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from scrapy) (4.9.3)
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.5.1)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Collecting constantly>=15.1 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Collecting incremental>=21.3.0 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting Automat>=0.8.0 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting hyperlink>=17.1.1 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.10/dist-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (4.5.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.6)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (2.31.0)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from Automat>=0.8.0->Twisted<23.8.0,>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2023.11.17)
# Installing collected packages: PyDispatcher, incremental, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, hyperlink, cssselect, constantly, Automat, Twisted, requests-file, parsel, tldextract, service-identity, itemloaders, scrapy
# Successfully installed Automat-22.10.0 PyDispatcher-2.0.7 Twisted-22.10.0 constantly-23.10.4 cssselect-1.2.0 hyperlink-21.0.0 incremental-22.10.0 itemadapter-0.8.0 itemloaders-1.1.0 jmespath-1.0.1 parsel-1.8.1 protego-0.3.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.11.0 service-identity-23.1.0 tldextract-5.1.1 w3lib-2.1.2 zope.interface-6.1

# %%
# !scrapy startproject WebCrawler
# Out:
# New Scrapy project 'WebCrawler', using template directory '/usr/local/lib/python3.10/dist-packages/scrapy/templates/project', created in:
#     /content/WebCrawler
#
# You can start your first spider with:
#     cd WebCrawler
#     scrapy genspider example example.com

# %%
# !cd WebCrawler && scrapy genspider boursorama https://www.boursorama.com/bourse/actions/palmares/france/page-1
# Out:
# Created spider 'boursorama' using template 'basic' in module:
#   WebCrawler.spiders.boursorama

# %% [markdown]
# ## Modifiez le fichier items.py en ajoutant les champs à collecter
#
# Ajoutez une class `ReviewsBoursoramaItem(scrapy.Item)` puis les champs avec la nomenclature `name = scrapy.Field()`

# %% [markdown]
# ## Lancez le shell scrapy

# %% [markdown]
# `scrapy shell`
#
# `url = 'https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC'`
#
# `fetch(url)`

# %% [markdown]
# ## Compléter le code suivant puis ajoutez-le au fichier `boursorama.py`.

# %%
import scrapy
from scrapy import Request
from WebCrawler.items import ReviewsBoursoramaItem
import datetime

class BoursoramaSpider(scrapy.Spider):
    name = 'boursorama'
    allowed_domains = ['finance.yahoo.com']
    start_urls = [f'https://www.boursorama.com/bourse/actions/palmares/france/page-{n}?france_filter%5Bmarket%5D=1rPCAC' for n in range(1,3)]

    def start_requests(self):
        for url in self.start_urls:
            yield Request(url=url, callback=self.parse_boursorama)

    def parse_boursorama(self, response):
        liste_indices = response.css('tr.c-table__row')[3:]

        for indices in liste_indices:
            item = ReviewsBoursoramaItem()

            #indice boursier
            try:item['indice'] = indices.css('a.c-link::text').get()
            except:item['indice'] = 'None'

            #indice cours de l'action
            try:item['cours'] = indices.css('span.c-instrument::text').get()
            except:item['cours'] = 'None'

            #Variation de l'action
            try:item['var'] = indices.css('span.c-instrument--instant-variation::text').get()
            except:item['var'] = 'None'

            #Valeur la plus haute
            try:item['high'] = indices.css('span.c-instrument--high::text').get()
            except:item['high'] = 'None'

            #Valeur la plus basse
            try:item['low'] = indices.css('span.c-instrument--low::text').get()
            except:item['low'] = 'None'

            #Valeur d'ouverture
            try:item['open_'] = indices.css('span.c-instrument--open::text').get()
            except:item['open_'] = 'None'

            #Date de la collecte
            try:item['time'] = datetime.datetime.now().strftime("%d-%m-%Y %H-%M")
            except:item['time'] = 'None'

            yield item

# %%
datetime.datetime.now().strftime("%d-%m-%Y %H-%M")
# Out:
# '13-12-2023 11-34'

# %% [markdown]
# ## Executez la commande suivante afin de collecter vos données

# %%
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl boursorama
# Out:
# Table : 'CAC40' are created succesfully
# 2024-01-04 12:10:30 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: WebCrawler)
# 2024-01-04 12:10:30 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.9.13, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.8.16 (default, Mar  1 2023, 21:19:10) - [Clang 14.0.6 ], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform macOS-10.16-x86_64-i386-64bit
# 2024-01-04 12:10:30 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-04 12:10:30 [asyncio] DEBUG: Using selector: KqueueSelector
# 2024-01-04 12:10:30 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-01-04 12:10:30 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-01-04 12:10:30 [scrapy.extensions.telnet] INFO: Telnet Password: aed8ff8fd0da1efb
# 2024-01-04 12:10:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-01-04 12:10:30 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'WebCrawler',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'WebCrawler.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['WebCrawler.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-01-04 12:10:30 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-01-04 12:10:30 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-01-04 12:10:30 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-01-04 12:10:30 [scrapy.core.engine] INFO: Spider opened
# 2024-01-04 12:10:30 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-04 12:10:30 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2024-01-04 12:10:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boursorama.com/robots.txt> (referer: None)
# 2024-01-04 12:10:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC> (referer: None)
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '139.060 ',
#  'high': '139.160 ',
#  'indice': 'AIRBUS',
#  'low': '137.500 ',
#  'open_': '137.580 ',
#  'time': '04-01-2024 12-10',
#  'var': '+1.39%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '11.285 ',
#  'high': '11.330 ',
#  'indice': 'ALSTOM',
#  'low': '11.115 ',
#  'open_': '11.170 ',
#  'time': '04-01-2024 12-10',
#  'var': '+2.92%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '60.300 ',
#  'high': '60.430 ',
#  'indice': 'DANONE',
#  'low': '60.100 ',
#  'open_': '60.300 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.43%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '61.770 ',
#  'high': '62.220 ',
#  'indice': 'BNP PARIBAS',
#  'low': '61.600 ',
#  'open_': '61.850 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.16%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '16.545 ',
#  'high': '16.715 ',
#  'indice': 'CARREFOUR',
#  'low': '16.505 ',
#  'open_': '16.645 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.54%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '187.000 ',
#  'high': '187.350 ',
#  'indice': 'CAPGEMINI',
#  'low': '186.300 ',
#  'open_': '186.350 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.27%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '29.790 ',
#  'high': '29.845 ',
#  'indice': 'AXA',
#  'low': '29.685 ',
#  'open_': '29.685 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.34%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '113.080 ',
#  'high': '113.260 ',
#  'indice': 'VINCI',
#  'low': '112.840 ',
#  'open_': '112.920 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.12%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '42.555 ',
#  'high': '42.900 ',
#  'indice': 'DASSAULT SYSTEMES',
#  'low': '42.535 ',
#  'open_': '42.900 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.91%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '54.160 ',
#  'high': '54.180 ',
#  'indice': 'EDENRED',
#  'low': '53.500 ',
#  'open_': '53.500 ',
#  'time': '04-01-2024 12-10',
#  'var': '+1.31%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '177.880 ',
#  'high': '181.000 ',
#  'indice': 'ESSILORLUXOTTICA',
#  'low': '177.740 ',
#  'open_': '178.760 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.77%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '34.560 ',
#  'high': '34.610 ',
#  'indice': 'BOUYGUES',
#  'low': '34.430 ',
#  'open_': '34.440 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.35%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '16.040 ',
#  'high': '16.040 ',
#  'indice': 'ENGIE',
#  'low': '15.850 ',
#  'open_': '15.850 ',
#  'time': '04-01-2024 12-10',
#  'var': '+1.26%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '57.840 ',
#  'high': '58.040 ',
#  'indice': 'EUROFINS SCIENTIFIC',
#  'low': '57.560 ',
#  'open_': '57.620 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.03%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '23.995 ',
#  'high': '24.080 ',
#  'indice': 'SOCIETE GENERALE',
#  'low': '23.890 ',
#  'open_': '23.905 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.23%'}
# 2024-01-04 12:10:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC> (referer: None)
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '136.450 ',
#  'high': '136.500 ',
#  'indice': 'THALES',
#  'low': '133.850 ',
#  'open_': '134.900 ',
#  'time': '04-01-2024 12-10',
#  'var': '+1.64%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '381.950 ',
#  'high': '382.650 ',
#  'indice': 'KERING',
#  'low': '379.700 ',
#  'open_': '381.150 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.21%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '91.500 ',
#  'high': '91.960 ',
#  'indice': 'LEGRAND',
#  'low': '91.080 ',
#  'open_': '91.560 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.20%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '698.800 ',
#  'high': '701.000 ',
#  'indice': 'LVMH',
#  'low': '693.400 ',
#  'open_': '693.500 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.49%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '32.010 ',
#  'high': '32.350 ',
#  'indice': 'MICHELIN',
#  'low': '31.920 ',
#  'open_': '32.290 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.56%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '437.250 ',
#  'high': '438.550 ',
#  'indice': "L'OREAL",
#  'low': '435.550 ',
#  'open_': '436.500 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.35%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '10.612 ',
#  'high': '10.642 ',
#  'indice': 'ORANGE',
#  'low': '10.586 ',
#  'open_': '10.604 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.08%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-1?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '84.160 ',
#  'high': '84.240 ',
#  'indice': 'PUBLICIS GROUPE',
#  'low': '83.560 ',
#  'open_': '83.720 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.62%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '36.170 ',
#  'high': '36.500 ',
#  'indice': 'RENAULT',
#  'low': '36.090 ',
#  'open_': '36.405 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.56%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '159.340 ',
#  'high': '159.540 ',
#  'indice': 'SAFRAN',
#  'low': '157.580 ',
#  'open_': '158.140 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.43%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '92.720 ',
#  'high': '93.190 ',
#  'indice': 'SANOFI',
#  'low': '92.520 ',
#  'open_': '92.520 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.80%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '64.140 ',
#  'high': '64.370 ',
#  'indice': 'SAINT-GOBAIN',
#  'low': '63.650 ',
#  'open_': '63.650 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.19%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '20.420 ',
#  'high': '20.565 ',
#  'indice': 'STELLANTIS',
#  'low': '20.360 ',
#  'open_': '20.470 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.17%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '42.995 ',
#  'high': '43.175 ',
#  'indice': 'STMICROELECTRONICS',
#  'low': '42.825 ',
#  'open_': '43.100 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.10%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '174.780 ',
#  'high': '175.480 ',
#  'indice': 'SCHNEIDER ELECTRIC',
#  'low': '174.120 ',
#  'open_': '174.700 ',
#  'time': '04-01-2024 12-10',
#  'var': '-0.08%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '129.500 ',
#  'high': '130.250 ',
#  'indice': 'TELEPERFORMANCE',
#  'low': '128.200 ',
#  'open_': '128.250 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.94%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '62.610 ',
#  'high': '62.750 ',
#  'indice': 'TOTALENERGIES',
#  'low': '62.050 ',
#  'open_': '62.180 ',
#  'time': '04-01-2024 12-10',
#  'var': '+1.41%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '67.520 ',
#  'high': '67.740 ',
#  'indice': 'UNIBAIL-RODAMCO-WESTFIELD',
#  'low': '66.420 ',
#  'open_': '66.420 ',
#  'time': '04-01-2024 12-10',
#  'var': '+1.50%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '28.510 ',
#  'high': '28.520 ',
#  'indice': 'VEOLIA',
#  'low': '28.260 ',
#  'open_': '28.260 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.85%'}
# Row id added
# 2024-01-04 12:10:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.boursorama.com/bourse/actions/palmares/france/page-2?france_filter%5Bmarket%5D=1rPCAC>
# {'cours': '9.674 ',
#  'high': '9.712 ',
#  'indice': 'VIVENDI',
#  'low': '9.648 ',
#  'open_': '9.648 ',
#  'time': '04-01-2024 12-10',
#  'var': '+0.02%'}
# 2024-01-04 12:10:31 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-01-04 12:10:31 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 807,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 173371,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 3,
#  'elapsed_time_seconds': 0.658674,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 1, 4, 11, 10, 31, 431678, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 1094508,
#  'httpcompression/response_count': 3,
#  'item_scraped_count': 35,
#  'log_count/DEBUG': 41,
#  'log_count/INFO': 10,
#  'memusage/max': 74387456,
#  'memusage/startup': 74387456,
#  'response_received_count': 3,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2024, 1, 4, 11, 10, 30, 773004, tzinfo=datetime.timezone.utc)}
# 2024-01-04 12:10:31 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# Import yahoo finance
import yfinance as yf

yf.download('BNP.PA', start='2021-01-01', end='2021-01-31')

yf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Import yahoo finance
# ----> 2 import yfinance as yf
#       4 yf.download('BNP.PA', start='2021-01-01', end='2021-01-31')
#       6 yf
#
# ModuleNotFoundError: No module named 'yfinance'

# %% [markdown]
# # Bonus - [MyAnimeListe](https://myanimelist.net/manga.php?letter=A)
#
# <img src='https://image.myanimelist.net/ui/OK6W_koKDTOqqqLDbIoPArR89MP-ulHxaLCJ2P-BfXg'>
#
# Reproduisez l'ensemble de la procédure en collectant les données du site [MyAnimeListe](https://myanimelist.net/manga.php?letter=A).
#
# Les données à collecter :
# - le nom des animés
# - l'image des animés
# - la description des animés.
#
# Utilisez la class `DataBase` pour stoquer vos donneés dans une base de données.

# %%
import sqlalchemy as db

class DataBase():
    def __init__(self, name_database='database'):
        self.name = name_database
        self.url = f"sqlite:///{name_database}.db"
        self.engine = db.create_engine(self.url)
        self.connection = self.engine.connect()
        self.metadata = db.MetaData()
        self.table = self.engine.table_names()


    def create_table(self, name_table, **kwargs):
        colums = [db.Column(k, v, primary_key = True) if 'id_' in k else db.Column(k, v) for k,v in kwargs.items()]
        db.Table(name_table, self.metadata, *colums)
        self.metadata.create_all(self.engine)
        print(f"Table : '{name_table}' are created succesfully")

    def read_table(self, name_table, return_keys=False):
        table = db.Table(name_table, self.metadata, autoload=True, autoload_with=self.engine)
        if return_keys:table.columns.keys()
        else : return table


    def add_row(self, name_table, **kwarrgs):
        name_table = self.read_table(name_table)

        stmt = (
            db.insert(name_table).
            values(kwarrgs)
        )
        self.connection.execute(stmt)
        print(f'Row id added')


    def delete_row_by_id(self, table, id_):
        name_table = self.read_table(name_table)

        stmt = (
            db.delete(name_table).
            where(students.c.id_ == id_)
            )
        self.connection.execute(stmt)
        print(f'Row id {id_} deleted')

    def select_table(self, name_table):
        name_table = self.read_table(name_table)
        stm = db.select([name_table])
        return self.connection.execute(stm).fetchall()

# %%
#Générer un projet scrapy
# !cd WebCrawler && scrapy genspider manga https://myanimelist.net/manga.php?letter=A

# Collecter les données
# !cd WebCrawler/WebCrawler/spiders && scrapy crawl (nom_du_projet::à compléter) -o (nom_du_fichier_CSV::à compléter)
